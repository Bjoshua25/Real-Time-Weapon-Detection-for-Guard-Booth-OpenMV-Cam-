# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup
import os
import time

# %%
def scrape_images(query, save_dir, num_images=100):
    """
    Scrapes images from a search engine and saves them to a directory.

    Args:
        query (str): The search term for the images.
        save_dir (str): The directory to save the images.
        num_images (int): The number of images to download.
    """
    
    # Create the directory if it doesn't exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
        print(f"Created directory: {save_dir}")
    
    # URL for a search engine image search
    # This example uses a simplified URL, you may need to find a more robust one
    # or use a library like `selenium` for dynamic pages.
    url = f'https://www.google.com/search?q={query}&tbm=isch'
    
    # Set a User-Agent to mimic a browser, preventing being blocked
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    
    print(f"Searching for images of: {query}...")
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()  # Raise an exception for bad status codes
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL: {e}")
        return

    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all 'img' tags
    img_tags = soup.find_all('img')
    
    downloaded_count = 0
    
    for i, img in enumerate(img_tags):
        if downloaded_count >= num_images:
            break
        
        try:
            # Get the image source URL, which may be in 'src' or 'data-src'
            img_url = img.get('src') or img.get('data-src')
            if not img_url:
                continue

            # Ensure the URL is a full HTTP/HTTPS link
            if img_url.startswith('http'):
                image_data = requests.get(img_url, headers=headers, timeout=10)
                image_data.raise_for_status()
                
                # Create a unique filename
                filename = f"{query.replace(' ', '_')}_{i:04d}.jpg"
                filepath = os.path.join(save_dir, filename)
                
                with open(filepath, 'wb') as f:
                    f.write(image_data.content)
                
                print(f"Downloaded: {filename}")
                downloaded_count += 1
                time.sleep(0.1) # Be a good citizen and don't flood the server
                
        except (requests.exceptions.RequestException, IOError) as e:
            print(f"Could not download image {i+1}: {e}")
            continue

    print(f"\nFinished scraping. Downloaded {downloaded_count} images to {save_dir}")

# --- Main script execution ---
base_dir = "dataset"

# Define your categories and corresponding search queries
categories = {
    "no_threat": ["empty room", "blank image", "empty guard booth"],
    "human_only": ["people walking", "people standing", "crowd of people"],
    "weapon_only": ["gun close up", "rifle isolated", "knife on table"],
    "human_with_weapon": ["soldier with rifle", "police officer with gun", "person holding a handgun"]
}

# Iterate through categories and scrape images
for category, queries in categories.items():
    category_path = os.path.join(base_dir, category)
    print(f"\n--- Starting to scrape for category: {category} ---")
    for query in queries:
        scrape_images(query, category_path, num_images=20) # Adjust num_images as needed
# Out:
# --- Starting to scrape for category: no_threat ---
# Created directory: dataset\no_threat
# Searching for images of: empty room...
# Error fetching URL: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: /search?q=empty%20room&tbm=isch (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD32E01C10>, 'Connection to www.google.com timed out. (connect timeout=None)'))
# Searching for images of: blank image...
# Error fetching URL: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Searching for images of: empty guard booth...
# Downloaded: empty_guard_booth_0001.jpg
# Downloaded: empty_guard_booth_0002.jpg
# Downloaded: empty_guard_booth_0003.jpg
# Downloaded: empty_guard_booth_0004.jpg
# Downloaded: empty_guard_booth_0005.jpg
# Could not download image 7: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRnFPcrQ2YTbv0DpEvcwIMP6dTQ2tt6HqmEAuZsSNII47TOmfMlQjMHDUtKNA&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD32ECD850>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: empty_guard_booth_0007.jpg
# Downloaded: empty_guard_booth_0008.jpg
# Downloaded: empty_guard_booth_0009.jpg
# Downloaded: empty_guard_booth_0010.jpg
# Downloaded: empty_guard_booth_0011.jpg
# Downloaded: empty_guard_booth_0012.jpg
# Downloaded: empty_guard_booth_0013.jpg
# Could not download image 15: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcSLeFEz1NjdK03r_UKK2AKVxtP3wVOdBOKywJz9dqVdgKhPjkeMWRHOPXmGdA&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD32ECFEC0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: empty_guard_booth_0015.jpg
# Downloaded: empty_guard_booth_0016.jpg
# Could not download image 18: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRtYHwAEI34RSf4fmkmpZxkCeFdP3yMnHYtaOfGcvXsobYI58lLK1--v57A6A&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD32EE44A0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Could not download image 19: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRMWnT7SXS7JxXjV-kEzQGsRDXu1hN1GO97Ja5jdLKtxKSl-ruWknTeGXCz3A&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD32ECE8D0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: empty_guard_booth_0019.jpg
# Downloaded: empty_guard_booth_0020.jpg
#
# Finished scraping. Downloaded 16 images to dataset\no_threat
#
# --- Starting to scrape for category: human_only ---
# Created directory: dataset\human_only
# Searching for images of: people walking...
# Downloaded: people_walking_0001.jpg
# Downloaded: people_walking_0002.jpg
# Downloaded: people_walking_0003.jpg
# Downloaded: people_walking_0004.jpg
# Downloaded: people_walking_0005.jpg
# Downloaded: people_walking_0006.jpg
# Downloaded: people_walking_0007.jpg
# Downloaded: people_walking_0008.jpg
# Could not download image 10: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcT1CI87RttQ22bO29eBIRX5R7EZPCxYuW4Ea7a4T_343Zf7DwfvaHMg9FhANx8&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33141460>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: people_walking_0010.jpg
# Downloaded: people_walking_0011.jpg
# Downloaded: people_walking_0012.jpg
# Downloaded: people_walking_0013.jpg
# Downloaded: people_walking_0014.jpg
# Downloaded: people_walking_0015.jpg
# Could not download image 17: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcTkzlIxjfXd571x-ogJUns_uaTAwmJphHEeidPlpQGE_15saHc0P4Y7vOTp4w&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33141610>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: people_walking_0017.jpg
# Downloaded: people_walking_0018.jpg
# Downloaded: people_walking_0019.jpg
# Could not download image 21: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRRUTvxgECVlZa3QK-jn_Jq6g16iagAy00zeRjaEcpMG7bOBx_OmGoB_aOmiQ&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33141D00>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
#
# Finished scraping. Downloaded 17 images to dataset\human_only
# Searching for images of: people standing...
# Could not download image 2: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRYhrvpB895JivMqtI2BGI0_ZT_d9fBlCS_uHwsEyxNPq26-_80lkEbjvGIBw&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD3312A150>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: people_standing_0002.jpg
# Downloaded: people_standing_0003.jpg
# Downloaded: people_standing_0004.jpg
# Downloaded: people_standing_0005.jpg
# Downloaded: people_standing_0006.jpg
# Downloaded: people_standing_0007.jpg
# Downloaded: people_standing_0008.jpg
# Downloaded: people_standing_0009.jpg
# Downloaded: people_standing_0010.jpg
# Downloaded: people_standing_0011.jpg
# Downloaded: people_standing_0012.jpg
# Could not download image 14: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcQe7Z-C8j360UGK_9JCouJJTkDQT8-tGXbw3MXVjZFn68dRDjKIMIFlshCSiP4&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33128470>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: people_standing_0014.jpg
# Downloaded: people_standing_0015.jpg
# Could not download image 17: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcR9BKwco3J815PPpJv6FiKaWsvoA3CtgCjb3cBbdlINgnSL9iLrMgeJl0vqB-c&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD32E033E0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Could not download image 18: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcSrB7iqFpW1EbIO4E0ruwZRc1ArzVzyu0ybM11mO7OEpjBQLlUyWRZvUOUUpy4&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD32ECE330>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Could not download image 19: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcR2s1cPU-F8OuN5TECEwbgGVv6vzBqpRkYlorapsqMZhbf1aZk-W4eRnyTbcA&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD31F5F080>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: people_standing_0019.jpg
# Downloaded: people_standing_0020.jpg
#
# Finished scraping. Downloaded 15 images to dataset\human_only
# Searching for images of: crowd of people...
# Downloaded: crowd_of_people_0001.jpg
# Downloaded: crowd_of_people_0002.jpg
# Downloaded: crowd_of_people_0003.jpg
# Downloaded: crowd_of_people_0004.jpg
# Downloaded: crowd_of_people_0005.jpg
# Downloaded: crowd_of_people_0006.jpg
# Downloaded: crowd_of_people_0007.jpg
# Downloaded: crowd_of_people_0008.jpg
# Downloaded: crowd_of_people_0009.jpg
# Downloaded: crowd_of_people_0010.jpg
# Downloaded: crowd_of_people_0011.jpg
# Downloaded: crowd_of_people_0012.jpg
# Could not download image 14: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRLJjwOgk1b6_8uqy3xC2s2yP3kfo41XXiUIR0s7ve8M904xv8NHm7pCDtw6Q&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD331B4A10>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: crowd_of_people_0014.jpg
# Could not download image 16: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcSRKPSCfDOZfWh6U5Euho6Zk_tzhx4CVHMqoQBc1ekNRce5okZ2LLdEtuzHUw&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD331B4CE0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: crowd_of_people_0016.jpg
# Downloaded: crowd_of_people_0017.jpg
# Downloaded: crowd_of_people_0018.jpg
# Downloaded: crowd_of_people_0019.jpg
# Downloaded: crowd_of_people_0020.jpg
#
# Finished scraping. Downloaded 18 images to dataset\human_only
#
# --- Starting to scrape for category: weapon_only ---
# Created directory: dataset\weapon_only
# Searching for images of: gun close up...
# Downloaded: gun_close_up_0001.jpg
# Could not download image 3: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRv2BnQiAqo9IvNT04yq6j9iKhPD2b09GbM07BH7tnvdZR9sjspBbqCFesbygE&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33217C20>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Could not download image 4: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcSrBT4aaDeFCGF6aUeUxOBipkR_QQbw1kzj1xjUpjcAcA2DKT3hBAs4bRiHMlQ&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD332305C0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: gun_close_up_0004.jpg
# Could not download image 6: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRzWa0sVY9WcoFxW96VKyTZUwOBpK2gCbItRcsVt7u5wHiHGW8qQRoMSQNIXWY&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD332174D0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Could not download image 7: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRzy_Gfy4cMzNI501A7f4sV6ZbRNIenXBAdPFUio61YA7_L7wdzNONUSe4XMA&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33231820>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Could not download image 8: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRUORmZYY2nS9WBUDf_RFTdKxfjGW4np9Cb6j8dyNR2fco5cX1OR-8CkbuKBJk&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD332321B0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: gun_close_up_0008.jpg
# Could not download image 10: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcRFYYhngyzmgX7AeSu99oyr9fGk0UTtiK8a_eFlAcg9V3PBTVWg315xrNiFtg&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33217BF0>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Downloaded: gun_close_up_0010.jpg
# Downloaded: gun_close_up_0011.jpg
# Downloaded: gun_close_up_0012.jpg
# Downloaded: gun_close_up_0013.jpg
# Downloaded: gun_close_up_0014.jpg
# Downloaded: gun_close_up_0015.jpg
# Downloaded: gun_close_up_0016.jpg
# Downloaded: gun_close_up_0017.jpg
# Could not download image 19: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcSM-XEvUOeqslv-n0RNLEdiQNdr6N71O5Xr4DNASKEAbeefQJK5QDoBcVZQv34&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33230890>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Could not download image 20: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcQdDTx0z0hUw49izVZx31LqD1QwW_0r-hjJGUBtL01As9t5BFQQrTA1s-ubyA&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33231A30>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
# Could not download image 21: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9GcQEh4o0Ds7PC7heRKckVievnSO8Bfx31Zo9Y_lcSpweEoLSvSh4z4K79vgN4A&s (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33230E60>, 'Connection to encrypted-tbn0.gstatic.com timed out. (connect timeout=10)'))
#
# Finished scraping. Downloaded 11 images to dataset\weapon_only
# Searching for images of: rifle isolated...
# Error fetching URL: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: /search?q=rifle%20isolated&tbm=isch (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33230230>, 'Connection to www.google.com timed out. (connect timeout=None)'))
# Searching for images of: knife on table...
# Error fetching URL: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: /search?q=knife%20on%20table&tbm=isch (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DD33232F00>, 'Connection to www.google.com timed out. (connect timeout=None)'))
#
# --- Starting to scrape for category: human_with_weapon ---
# Created directory: dataset\human_with_weapon
# Searching for images of: soldier with rifle...
# Downloaded: soldier_with_rifle_0001.jpg
# Downloaded: soldier_with_rifle_0002.jpg
# Could not download image 4: HTTPSConnectionPool(host='encrypted-tbn0.gstatic.com', port=443): Max retries exceeded with url: /images?q=tbn:ANd9Gc