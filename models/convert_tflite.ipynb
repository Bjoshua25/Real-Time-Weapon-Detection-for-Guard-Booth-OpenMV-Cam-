# %%
# Libraries

import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.mobilenet import preprocess_input
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# === LOAD DATA ===
dataset = "dataset_rgb_224_binary_balanced.npz"
data = np.load(dataset, allow_pickle=True)
X_train, y_train = data["X_train"], data["y_train"]
X_val, y_val = data["X_val"], data["y_val"]
X_test, y_test = data["X_test"], data["y_test"]
label_names = data["label_names"]
num_classes = len(label_names)
img_size = (224, 224)

print(f"Loaded dataset with {len(X_train)} training, {len(X_val)} validation, and {len(X_test)} test samples.")
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
print(f"Classes: {label_names}")
# Out:
# Loaded dataset with 2501 training, 536 validation, and 536 test samples.
# X_train shape: (2501, 224, 224, 3), y_train shape: (2501,)
# X_val shape: (536, 224, 224, 3), y_val shape: (536,)
# X_test shape: (536, 224, 224, 3), y_test shape: (536,)
# Classes: ['NO_THREAT' 'THREAT']

# %%
import numpy as np
import tensorflow as tf

# === LOAD DATA ===
dataset = "dataset_rgb_224_binary_balanced.npz"
data = np.load(dataset, allow_pickle=True)
X_train, y_train = data["X_train"], data["y_train"]
X_val, y_val = data["X_val"], data["y_val"]
X_test, y_test = data["X_test"], data["y_test"]
label_names = data["label_names"]
img_size = (224, 224)

print(f"Loaded dataset with {len(X_train)} training, {len(X_val)} validation, and {len(X_test)} test samples.")
print(f"Classes: {label_names}")

# === LOAD TRAINED MODEL ===
model = tf.keras.models.load_model("mobilenetv2_best_model.h5")

# === REPRESENTATIVE DATASET GENERATOR ===
def representative_data_gen():
    for i in range(100):
        img = X_train[i]
        img = np.expand_dims(img, axis=0).astype(np.float32)
        yield [img]

# === CONVERTER SETTINGS FOR OPENMV ===
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Optimization
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Calibration dataset for quantization
converter.representative_dataset = representative_data_gen

# Force FULL int8 quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8   # OpenMV requires int8, NOT uint8
converter.inference_output_type = tf.int8

# === PERFORM CONVERSION ===
tflite_model = converter.convert()

# === SAVE FILE ===
with open("mobilenetv2_224_int8.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ Saved: mobilenetv2_224_int8.tflite (INT8 I/O, OpenMV compatible)")
# Out:
# Loaded dataset with 2501 training, 536 validation, and 536 test samples.
# Classes: ['NO_THREAT' 'THREAT']
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmp07nobljg\assets
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmp07nobljg\assets
# Saved artifact at 'C:\Users\user\AppData\Local\Temp\tmp07nobljg'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   2663222361936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873479504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873478928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873479696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873479120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663222361744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873481616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873481808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873479888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873479312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663222358672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873482000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873482768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873482384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873481232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873478736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873483536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873483344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873480656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873484112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873480464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873483728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873483920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873483152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873485072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873484496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873484688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873484880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873482960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873486032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873485456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873485648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873485840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873480080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873486992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663222360976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873486800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873487184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873486224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873487760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663222361360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873487568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873487952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873485264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873488528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873486416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873486608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873488336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873484304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873489488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873488912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873489104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873489296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873488144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873490448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873489872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873490064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873490256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873487376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873491408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873490832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873491024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873491216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873488720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873492368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873491792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873491984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873492176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873489680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873493328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873492752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873492944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873493136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873490640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873494288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873493712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873493904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873494480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873494864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873493520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873492560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873494096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873839760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873494672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873491600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873839184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873840144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873839952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873839376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873841296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873840720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873840912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873841104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873840336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873842256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873841680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873841872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873842064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873839568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873843216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873842640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873842832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873843024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873840528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873844176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873843600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873843792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873843984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873841488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873845136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873844560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873844752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873844944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873842448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873846096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873845520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873845712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873845904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873843408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873847056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873846480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873846672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873846864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873844368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873848016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873847440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873847632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873847824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873845328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873848976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873848400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873848592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873848784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873846288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873849360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873849552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873847248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873850896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873850512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873850704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873848208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873851856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873851280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873851472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873851664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873849168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873852816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873852240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873852432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873852624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873850128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873853776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873853200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873853392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873853584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873851088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873854736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873854160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873854352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873854928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873855312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873853968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873853008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873854544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874184400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873855120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663873852048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874183440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874183824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874184016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874184208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874185360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874184784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874184976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874185168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874183248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874185744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874185936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874186128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874183632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874187280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874186704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874186896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874187088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874184592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874188240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874187664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874187856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874188048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874185552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874189200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874188624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874188816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874189008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874186512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874190160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874189584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874189776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874189968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874187472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874191120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874190544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874190736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874190928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874188432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874192080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874191504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874191696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874191888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874189392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874193040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874192464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874192656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874192848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874190352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874194000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874193424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874193616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874193808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874191312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874194960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874194384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874194576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874194768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874192272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874195920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874195344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874195536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874195728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874193232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874196880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874196304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874196496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874196688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874194192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874197840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874197264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874197456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874197648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874195152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874198800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874198224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874198416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874198992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874199376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874198032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874197072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874198608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892190416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874199184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663874196112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892189456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892189840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892190032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892190224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892191376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892190608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892190992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892192336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2663892191568: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\user\anaconda3\Lib\site-packages\tensorflow\lite\python\convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# ✅ Saved: mobilenetv2_224_int8.tflite (INT8 I/O, OpenMV compatible)
