# %%
# Libraries

import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.mobilenet import preprocess_input
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# === LOAD DATA ===
dataset = "dataset_rgb_224_binary_balanced.npz"
data = np.load(dataset, allow_pickle=True)
X_train, y_train = data["X_train"], data["y_train"]
X_val, y_val = data["X_val"], data["y_val"]
X_test, y_test = data["X_test"], data["y_test"]
label_names = data["label_names"]
num_classes = len(label_names)
img_size = (224, 224)

print(f"Loaded dataset with {len(X_train)} training, {len(X_val)} validation, and {len(X_test)} test samples.")
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
print(f"Classes: {label_names}")
# Out:
# Loaded dataset with 2501 training, 536 validation, and 536 test samples.
# X_train shape: (2501, 224, 224, 3), y_train shape: (2501,)
# X_val shape: (536, 224, 224, 3), y_val shape: (536,)
# X_test shape: (536, 224, 224, 3), y_test shape: (536,)
# Classes: ['NO_THREAT' 'THREAT']

# %%
# === Load your trained Keras model ===
model = tf.keras.models.load_model("mobilenetv2_best_model.h5")

# === Define a representative dataset generator ===
# This helps TF calibrate ranges for int8 quantization.
# Use some training/validation images (not all) to speed up conversion.
def representative_data_gen():
    for i in range(100):
        # Pick random samples from X_train
        img = X_train[i]
        img = np.expand_dims(img, axis=0).astype(np.float32)
        yield [img]

# === Convert to int8 TFLite ===
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Optimization flag
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Representative dataset for proper quantization
converter.representative_dataset = representative_data_gen

# Force int8 I/O (needed for OpenMV)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.uint8
converter.inference_output_type = tf.uint8

# Perform conversion
tflite_model = converter.convert()

# Save to file
with open("mobilenetv2_224_int8.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ TFLite int8 model saved as mobilenetv2_224_int8.tflite")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmpdy4v4s8l\assets
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmpdy4v4s8l\assets
# Saved artifact at 'C:\Users\user\AppData\Local\Temp\tmpdy4v4s8l'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   2143911310736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911311888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911312080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911309392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911312656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911311696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911312272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911312848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911313232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911310160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911310544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911312464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934431696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911313040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143911306704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934431504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934432272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934432080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934431888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934433424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934432848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934433040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934433232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934432464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934434384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934433808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934434000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934434192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934431312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934435344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934434768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934434960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934435152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934432656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934436304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934435728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934435920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934436112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934433616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934437264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934436688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934436880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934437072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934434576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934438224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934437648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934437840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934438032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934435536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934439184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934438608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934438800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934438992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934436496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934440144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934439568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934439760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934439952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934437456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934441104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934440528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934440720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934440912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934438416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934442064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934441488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934441680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934441872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934439376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934443024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934442448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934442640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934442832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934440336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934443984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934443408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934443600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934443792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934441296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934444944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934444368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934444560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934444752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934442256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934445904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934445328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934445520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934445712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934443216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934446864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934446288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934446480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934447056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934447440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934446096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934445136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934446672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934530192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934447248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934444176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934529616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934530576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934530384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934529808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934531728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934531152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934531344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934531536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934530768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934532688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934532112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934532304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934532496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934530000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934533648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934533072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934533264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934533456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934530960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934534608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934534032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934534224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934534416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934531920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934535568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934534992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934535184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934535376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934532880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934536528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934535952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934536144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934536336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934533840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934537488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934536912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934537104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934537296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934534800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934538448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934537872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934538064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934535760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934539408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934538832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934539024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934539216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934536720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934540368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934539792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934539984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934540176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934537680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934541328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934540752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934540944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934541136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934538640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934542288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934541712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934541904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934542096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934539600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934543248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934542672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934542864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934543056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934540560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934544208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934543632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934543824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934544016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934541520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934545168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934544592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934544784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934545360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934545744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934544400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934543440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934544976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934973136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934545552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934542480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934972176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934972560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934972752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934972944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934974096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934973520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934973712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934973904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934971984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934975056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934974480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934974672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934974864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934972368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934976016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934975440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934975632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934975824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934973328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934976976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934976400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934976592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934976784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934974288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934977936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934977360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934977552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934977744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934975248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934978896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934978320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934978512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934978704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934976208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934979856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934979280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934979472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934979664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934977168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934980816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934980240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934980432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934980624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934978128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934981776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934981200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934981392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934981584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934979088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934982736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934982160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934982352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934982544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934980048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934983696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934983120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934983312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934983504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934981008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934984656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934984080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934984272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934984464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934981968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934985616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934985040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934985232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934985424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934982928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934986576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934986000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934986192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934986384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934983888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934987536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934985808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934988112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934986960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2143934987152: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\user\anaconda3\Lib\site-packages\tensorflow\lite\python\convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# ✅ TFLite int8 model saved as mobilenetv2_224_int8.tflite
