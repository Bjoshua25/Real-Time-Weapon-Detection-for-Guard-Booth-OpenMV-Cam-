# %%
# Libraries

import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.mobilenet import preprocess_input
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
# === LOAD DATA ===
dataset = "dataset_rgb_224_binary_balanced.npz"
data = np.load(dataset, allow_pickle=True)
X_train = data["X_train"]
y_train = data["y_train"]

print(f"Loaded dataset with {len(X_train)} training samples.")
# Out:
# Loaded dataset with 2501 training samples.

# %%
# === LOAD TRAINED MODEL ===
model = tf.keras.models.load_model("mobilenetv2_best_model.h5")

# === REPRESENTATIVE DATASET GENERATOR ===
# The generator must produce preprocessed data to match the training pipeline.
def representative_data_gen():
    """Generator for the representative dataset with correct preprocessing."""
    for i in range(1000):
        # Get a raw image from the training set
        img = X_train[i]
        # Expand dimensions to (1, 224, 224, 3) and convert to float32
        img = np.expand_dims(img, axis=0).astype(np.float32)
        
        # === IMPORTANT FIX ===
        # Apply the same preprocessing function used during training.
        # This function normalizes the pixel values from [0, 255] to [-1, 1].
        preprocessed_img = preprocess_input(img)
        
        yield [preprocessed_img]

# === CONVERTER SETTINGS FOR OPENMV ===
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Optimization
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Calibration dataset for quantization
converter.representative_dataset = representative_data_gen

# Force FULL int8 quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

# === PERFORM CONVERSION ===
tflite_model = converter.convert()

# === SAVE FILE ===
with open("mobilenetv2_224_int8_corrected.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ Saved: mobilenetv2_224_int8_corrected.tflite (INT8 I/O, OpenMV compatible)")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmpwph1ffvf\assets
# INFO:tensorflow:Assets written to: C:\Users\user\AppData\Local\Temp\tmpwph1ffvf\assets
# Saved artifact at 'C:\Users\user\AppData\Local\Temp\tmpwph1ffvf'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   1878962928144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1878962928528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1878962927952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1878962929488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1878962928912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1878962928336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474371664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474371856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474370512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474371088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1878962929104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474372816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474373008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474370704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474371280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474370320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474373776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474373584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474370128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474374352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474372432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474373968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474374160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474373392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474375312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474374736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474374928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474375120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474373200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474376272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474375696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474375888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474376080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474372048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474377232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1878962927184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474377040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474377424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474376464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474378000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1878962927568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474377808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474378192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474375504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474378768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474376656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474376848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474378576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474374544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474379728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474379152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474379344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474379536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474378384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474380688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474380112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474380304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474380496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474377616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474381648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474381072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474381264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474381456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474378960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474382608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474382032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474382224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474382416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474379920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474383568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474382992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474383184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474383376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474380880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474384528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474383952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474384144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474384336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474381840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474385488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474384912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474385104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474384720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474386256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474385680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474383760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474385872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474386064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474385296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474382800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474714384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474714768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474714960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474714576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474716112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474715536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474715728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474715920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474715152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474717072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474716496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474716688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474716880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474714192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474718032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474717456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474717648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474717840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474715344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474718992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474718416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474718608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474718800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474716304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474719952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474719376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474719568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474719760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474717264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474720912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474720336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474720528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474720720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474718224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474721872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474721296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474721488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474721680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474719184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474722832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474722256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474722448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474722640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474720144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474723792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474723216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474723408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474723600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474721104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474724752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474724176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474724368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474724560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474722064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474725712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474725136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474725328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474725520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474723024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474726672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474726096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474726288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474726480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474723984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474727632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474727056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474727248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474727440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474724944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474728592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474728016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474728208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474728400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474725904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474729552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474728976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474729168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474728784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474730320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474729744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474727824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474729936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474730128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474729360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880474726864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475123984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475125136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475124944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475124560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475125712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475124176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475125328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475125520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475123792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475126672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475126096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475126288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475126480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475124368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475127632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475127056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475127248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475127440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475124752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475128592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475128016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475128208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475128400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475125904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475129552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475128976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475129168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475129360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475126864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475130512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475129936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475130128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475130320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475127824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475131472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475130896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475131088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475131280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475128784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475132432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475131856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475132048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475132240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475129744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475133392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475132816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475133008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475133200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475130704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475134352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475133776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475133968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475134160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475131664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475135312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475134736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475134928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475135120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475132624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475136272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475135696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475135888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475136080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475133584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475137232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475136656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475136848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475137040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475134544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475138192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475137616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475137808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475138000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475135504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475139152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475138576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475138768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475138384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475139920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475139344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475137424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475139536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475139728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475138960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880475136464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880493228688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880493229456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880493230032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1880493229072: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\user\anaconda3\Lib\site-packages\tensorflow\lite\python\convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# ✅ Saved: mobilenetv2_224_int8_corrected.tflite (INT8 I/O, OpenMV compatible)
